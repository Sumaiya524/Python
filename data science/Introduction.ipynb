# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumaiya524/Python/blob/main/data%20science/Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Welcome!')
# Out:
# Welcome!

# %%
57+49
# Out:
# 106
